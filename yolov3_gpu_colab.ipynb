# %% [markdown]
# <a href="https://colab.research.google.com/github/ouardaoui/ML/blob/master/yolov3_gpu_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # YoloV3 TF2 GPU Colab Notebook
# ##### 1.  Clone and install dependencies

# %%
# !git clone https://github.com/zzh8829/yolov3-tf2
# %cd yolov3-tf2/
# !pip install -r requirements-gpu.txt
# Out:
# Cloning into 'yolov3-tf2'...
# remote: Enumerating objects: 400, done.
# remote: Total 400 (delta 0), reused 0 (delta 0), pack-reused 400
# Receiving objects: 100% (400/400), 4.23 MiB | 14.93 MiB/s, done.
# Resolving deltas: 100% (231/231), done.
# /content/yolov3-tf2
# Obtaining file:///content/yolov3-tf2 (from -r requirements-gpu.txt (line 6))
# Collecting tensorflow-gpu==2.4.0
#   Downloading https://files.pythonhosted.org/packages/f1/aa/ae64be5acaac9055329289e6bfd54c1efa28bfe792f9021cea495fe2b89d/tensorflow_gpu-2.4.0-cp36-cp36m-manylinux2010_x86_64.whl (394.7MB)
#      |████████████████████████████████| 394.7MB 41kB/s
# Collecting opencv-python==4.1.1.26
#   Downloading https://files.pythonhosted.org/packages/5e/7e/bd5425f4dacb73367fddc71388a47c1ea570839197c2bcad86478e565186/opencv_python-4.1.1.26-cp36-cp36m-manylinux1_x86_64.whl (28.7MB)
#      |████████████████████████████████| 28.7MB 161kB/s
# Requirement already satisfied: lxml in /usr/local/lib/python3.6/dist-packages (from -r requirements-gpu.txt (line 3)) (4.2.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from -r requirements-gpu.txt (line 4)) (4.41.1)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.4.0->-r requirements-gpu.txt (line 1)) (1.1.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.4.0->-r requirements-gpu.txt (line 1)) (3.7.4.3)
# Requirement already satisfied: wrapt~=1.12.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.4.0->-r requirements-gpu.txt (line 1)) (1.12.1)
# Requirement already satisfied: flatbuffers~=1.12.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.4.0->-r requirements-gpu.txt (line 1)) (1.12)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.4.0->-r requirements-gpu.txt (line 1)) (0.36.2)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.4.0->-r requirements-gpu.txt (line 1)) (1.1.2)
# Requirement already satisfied: six~=1.15.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.4.0->-r requirements-gpu.txt (line 1)) (1.15.0)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.4.0->-r requirements-gpu.txt (line 1)) (1.6.3)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.4.0->-r requirements-gpu.txt (line 1)) (0.2.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.4.0->-r requirements-gpu.txt (line 1)) (3.12.4)
# Requirement already satisfied: tensorboard~=2.4 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.4.0->-r requirements-gpu.txt (line 1)) (2.4.1)
# Requirement already satisfied: grpcio~=1.32.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.4.0->-r requirements-gpu.txt (line 1)) (1.32.0)
# Requirement already satisfied: tensorflow-estimator<2.5.0,>=2.4.0rc0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.4.0->-r requirements-gpu.txt (line 1)) (2.4.0)
# Requirement already satisfied: h5py~=2.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.4.0->-r requirements-gpu.txt (line 1)) (2.10.0)
# Requirement already satisfied: gast==0.3.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.4.0->-r requirements-gpu.txt (line 1)) (0.3.3)
# Requirement already satisfied: numpy~=1.19.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.4.0->-r requirements-gpu.txt (line 1)) (1.19.5)
# Requirement already satisfied: opt-einsum~=3.3.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.4.0->-r requirements-gpu.txt (line 1)) (3.3.0)
# Requirement already satisfied: absl-py~=0.10 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.4.0->-r requirements-gpu.txt (line 1)) (0.10.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.9.2->tensorflow-gpu==2.4.0->-r requirements-gpu.txt (line 1)) (53.0.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard~=2.4->tensorflow-gpu==2.4.0->-r requirements-gpu.txt (line 1)) (1.8.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard~=2.4->tensorflow-gpu==2.4.0->-r requirements-gpu.txt (line 1)) (2.23.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard~=2.4->tensorflow-gpu==2.4.0->-r requirements-gpu.txt (line 1)) (3.3.3)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard~=2.4->tensorflow-gpu==2.4.0->-r requirements-gpu.txt (line 1)) (1.25.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard~=2.4->tensorflow-gpu==2.4.0->-r requirements-gpu.txt (line 1)) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard~=2.4->tensorflow-gpu==2.4.0->-r requirements-gpu.txt (line 1)) (0.4.2)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow-gpu==2.4.0->-r requirements-gpu.txt (line 1)) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow-gpu==2.4.0->-r requirements-gpu.txt (line 1)) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow-gpu==2.4.0->-r requirements-gpu.txt (line 1)) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow-gpu==2.4.0->-r requirements-gpu.txt (line 1)) (2.10)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard~=2.4->tensorflow-gpu==2.4.0->-r requirements-gpu.txt (line 1)) (3.4.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow-gpu==2.4.0->-r requirements-gpu.txt (line 1)) (4.2.1)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow-gpu==2.4.0->-r requirements-gpu.txt (line 1)) (4.7)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow-gpu==2.4.0->-r requirements-gpu.txt (line 1)) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow-gpu==2.4.0->-r requirements-gpu.txt (line 1)) (1.3.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard~=2.4->tensorflow-gpu==2.4.0->-r requirements-gpu.txt (line 1)) (3.4.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow-gpu==2.4.0->-r requirements-gpu.txt (line 1)) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow-gpu==2.4.0->-r requirements-gpu.txt (line 1)) (3.1.0)
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: tensorflow-gpu, opencv-python, yolov3-tf2
#   Found existing installation: opencv-python 4.1.2.30
#     Uninstalling opencv-python-4.1.2.30:
#       Successfully uninstalled opencv-python-4.1.2.30
#   Running setup.py develop for yolov3-tf2
# Successfully installed opencv-python-4.1.1.26 tensorflow-gpu-2.4.0 yolov3-tf2

# %% [markdown]
# ####2.  Check Tensorflow2 version

# %%
# %cd yolov3-tf2/
# !ls

import tensorflow as tf
tf.__version__
# Out:
# [Errno 2] No such file or directory: 'yolov3-tf2/'
# /content/yolov3-tf2
# checkpoints	 data		  README.md		train.py
# colab_gpu.ipynb  detect.py	  requirements-gpu.txt	yolov3_tf2
# conda-cpu.yml	 detect_video.py  requirements.txt	yolov3_tf2.egg-info
# conda-gpu.yml	 docs		  setup.py
# convert.py	 LICENSE	  tools
# '2.4.0'

# %% [markdown]
# ##### 3.  Convert Pretrained Darknet Weight

# %%
# !wget https://pjreddie.com/media/files/yolov3.weights -O data/yolov3.weights
# !python convert.py
# Out:
# --2021-02-09 15:00:26--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘data/yolov3.weights’
#
# data/yolov3.weights 100%[===================>] 236.52M  1.21MB/s    in 3m 53s
#
# 2021-02-09 15:04:19 (1.01 MB/s) - ‘data/yolov3.weights’ saved [248007048/248007048]
#
# 2021-02-09 15:04:20.365365: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2021-02-09 15:04:20.365423: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2021-02-09 15:04:22.592244: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-02-09 15:04:22.617485: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-02-09 15:04:22.677550: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2021-02-09 15:04:22.677630: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (89090a21016f): /proc/driver/nvidia/version does not exist
# 2021-02-09 15:04:22.705967: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# Model: "yolov3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, None, None,  0
# __________________________________________________________________________________________________
# yolo_darknet (Functional)       ((None, None, None,  40620640    input[0][0]
# __________________________________________________________________________________________________
# yolo_conv_0 (Functional)        (None, None, None, 5 11024384    yolo_darknet[0][2]
# __________________________________________________________________________________________________
# yolo_conv_1 (Functional)        (None, None, None, 2 2957312     yolo_conv_0[0][0]
#                                                                  yolo_darknet[0][1]
# __________________________________________________________________________________________________
# yolo_conv_2 (Functional)        (None, None, None, 1 741376      yolo_conv_1[0][0]
#                                                                  yolo_darknet[0][0]
# __________________________________________________________________________________________________
# yolo_output_0 (Functional)      (None, None, None, 3 4984063     yolo_conv_0[0][0]
# __________________________________________________________________________________________________
# yolo_output_1 (Functional)      (None, None, None, 3 1312511     yolo_conv_1[0][0]
# __________________________________________________________________________________________________
# yolo_output_2 (Functional)      (None, None, None, 3 361471      yolo_conv_2[0][0]
# __________________________________________________________________________________________________
# yolo_boxes_0 (Lambda)           ((None, None, None,  0           yolo_output_0[0][0]
# __________________________________________________________________________________________________
# yolo_boxes_1 (Lambda)           ((None, None, None,  0           yolo_output_1[0][0]
# __________________________________________________________________________________________________
# yolo_boxes_2 (Lambda)           ((None, None, None,  0           yolo_output_2[0][0]
# __________________________________________________________________________________________________
# yolo_nms (Lambda)               ((None, 100, 4), (No 0           yolo_boxes_0[0][0]
#                                                                  yolo_boxes_0[0][1]
#                                                                  yolo_boxes_0[0][2]
#                                                                  yolo_boxes_1[0][0]
#                                                                  yolo_boxes_1[0][1]
#                                                                  yolo_boxes_1[0][2]
#                                                                  yolo_boxes_2[0][0]
#                                                                  yolo_boxes_2[0][1]
#                                                                  yolo_boxes_2[0][2]
# ==================================================================================================
# Total params: 62,001,757
# Trainable params: 61,949,149
# Non-trainable params: 52,608
# __________________________________________________________________________________________________
# I0209 15:04:25.692806 139804956100480 convert.py:24] model created
# I0209 15:04:25.694462 139804956100480 utils.py:45] yolo_darknet/conv2d bn
# I0209 15:04:25.696885 139804956100480 utils.py:45] yolo_darknet/conv2d_1 bn
# I0209 15:04:25.698934 139804956100480 utils.py:45] yolo_darknet/conv2d_2 bn
# I0209 15:04:25.700901 139804956100480 utils.py:45] yolo_darknet/conv2d_3 bn
# I0209 15:04:25.702899 139804956100480 utils.py:45] yolo_darknet/conv2d_4 bn
# I0209 15:04:25.705285 139804956100480 utils.py:45] yolo_darknet/conv2d_5 bn
# I0209 15:04:25.707335 139804956100480 utils.py:45] yolo_darknet/conv2d_6 bn
# I0209 15:04:25.711039 139804956100480 utils.py:45] yolo_darknet/conv2d_7 bn
# I0209 15:04:25.714431 139804956100480 utils.py:45] yolo_darknet/conv2d_8 bn
# I0209 15:04:25.718245 139804956100480 utils.py:45] yolo_darknet/conv2d_9 bn
# I0209 15:04:25.722682 139804956100480 utils.py:45] yolo_darknet/conv2d_10 bn
# I0209 15:04:25.724841 139804956100480 utils.py:45] yolo_darknet/conv2d_11 bn
# I0209 15:04:25.728163 139804956100480 utils.py:45] yolo_darknet/conv2d_12 bn
# I0209 15:04:25.730330 139804956100480 utils.py:45] yolo_darknet/conv2d_13 bn
from yolov3_tf2.dataset import transform_images, load_tfrecord_dataset
from yolov3_tf2.utils import draw_outputs

flags.DEFINE_string('classes', './data/coco.names', 'path to classes file')
flags.DEFINE_string('weights', './checkpoints/yolov3.tf',
                    'path to weights file')
flags.DEFINE_boolean('tiny', False, 'yolov3 or yolov3-tiny')
flags.DEFINE_integer('size', 416, 'resize images to')
flags.DEFINE_string('image', './data/girl.png', 'path to input image')
flags.DEFINE_string('tfrecord', None, 'tfrecord instead of image')
flags.DEFINE_string('output', './output.jpg', 'path to output image')
flags.DEFINE_integer('num_classes', 80, 'number of classes in the model')

app._run_init(['yolov3'], app.parse_flags_with_usage)

physical_devices = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %% [markdown]
# ##### 4. Detect Image

# %%
FLAGS.image = 'data/meme2.jpeg'

if FLAGS.tiny:
    yolo = YoloV3Tiny(classes=FLAGS.num_classes)
else:
    yolo = YoloV3(classes=FLAGS.num_classes)
      
yolo.load_weights(FLAGS.weights).expect_partial()
logging.info('weights loaded')

class_names = [c.strip() for c in open(FLAGS.classes).readlines()]
logging.info('classes loaded')

img_raw = tf.image.decode_image(
    open(FLAGS.image, 'rb').read(), channels=3)

img = tf.expand_dims(img_raw, 0)
img = transform_images(img, FLAGS.size)

t1 = time.time()
boxes, scores, classes, nums = yolo(img)
t2 = time.time()
logging.info('time: {}'.format(t2 - t1))

logging.info('detections:')
for i in range(nums[0]):
    logging.info('\t{}, {}, {}'.format(class_names[int(classes[0][i])],
                                        np.array(scores[0][i]),
                                        np.array(boxes[0][i])))

img = cv2.cvtColor(img_raw.numpy(), cv2.COLOR_RGB2BGR)
img = draw_outputs(img, (boxes, scores, classes, nums), class_names)

from IPython.display import Image, display
display(Image(data=bytes(cv2.imencode('.jpg', img)[1]), width=800))
# Out:
# I0209 15:29:16.444690 139897146165120 <ipython-input-11-f3d7c4ec7062>:9] weights loaded
# I0209 15:29:16.446295 139897146165120 <ipython-input-11-f3d7c4ec7062>:12] classes loaded
# I0209 15:29:17.826928 139897146165120 <ipython-input-11-f3d7c4ec7062>:23] time: 1.3694026470184326
# I0209 15:29:17.827964 139897146165120 <ipython-input-11-f3d7c4ec7062>:25] detections:
# I0209 15:29:17.831503 139897146165120 <ipython-input-11-f3d7c4ec7062>:29] 	person, 0.9996727108955383, [0.10497868 0.17179078 0.47821975 0.99576515]
# I0209 15:29:17.840311 139897146165120 <ipython-input-11-f3d7c4ec7062>:29] 	person, 0.9956490397453308, [0.4560235  0.06149828 0.7274452  0.98329854]
# I0209 15:29:17.843086 139897146165120 <ipython-input-11-f3d7c4ec7062>:29] 	person, 0.9572049379348755, [0.7069311  0.22946662 0.91559696 1.        ]
# I0209 15:29:17.846899 139897146165120 <ipython-input-11-f3d7c4ec7062>:29] 	person, 0.9102912545204163, [0.93971944 0.43444303 1.         0.89688945]
# I0209 15:29:17.850082 139897146165120 <ipython-input-11-f3d7c4ec7062>:29] 	person, 0.624756395816803, [0.08753047 0.41167545 0.18400961 0.7732612 ]

# %% [markdown]
# ##### 5. Training New Dataset

# %%
# !wget http://host.robots.ox.ac.uk/pascal/VOC/voc2009/VOCtrainval_11-May-2009.tar -O ./data/voc2009_raw.tar
# !mkdir -p ./data/voc2009_raw
# !tar -xf ./data/voc2009_raw.tar -C ./data/voc2009_raw
# Out:
# --2021-02-09 15:31:36--  http://host.robots.ox.ac.uk/pascal/VOC/voc2009/VOCtrainval_11-May-2009.tar
# Resolving host.robots.ox.ac.uk (host.robots.ox.ac.uk)... 129.67.94.152
# Connecting to host.robots.ox.ac.uk (host.robots.ox.ac.uk)|129.67.94.152|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 935534080 (892M) [application/x-tar]
# Saving to: ‘./data/voc2009_raw.tar’
#
# ./data/voc2009_raw. 100%[===================>] 892.19M  11.7MB/s    in 73s
#
# 2021-02-09 15:32:50 (12.1 MB/s) - ‘./data/voc2009_raw.tar’ saved [935534080/935534080]

# %%
# !python tools/voc2012.py \
  --data_dir './data/voc2009_raw/VOCdevkit/VOC2009' \
  --split train \
  --output_file ./data/voc_train.tfrecord

# !python tools/voc2012.py \
  --data_dir './data/voc2009_raw/VOCdevkit/VOC2009' \
  --split val \
  --output_file ./data/voc_val.tfrecord
# Out:
# 2021-02-09 15:42:38.881187: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2021-02-09 15:42:38.881244: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# I0209 15:42:41.682028 140615200499584 voc2012.py:92] Class mapping loaded: {'aeroplane': 0, 'bicycle': 1, 'bird': 2, 'boat': 3, 'bottle': 4, 'bus': 5, 'car': 6, 'cat': 7, 'chair': 8, 'cow': 9, 'diningtable': 10, 'dog': 11, 'horse': 12, 'motorbike': 13, 'person': 14, 'pottedplant': 15, 'sheep': 16, 'sofa': 17, 'train': 18, 'tvmonitor': 19}
# I0209 15:42:41.683408 140615200499584 voc2012.py:97] Image list loaded: 3473
# 100% 3473/3473 [00:04<00:00, 789.93it/s]
# I0209 15:42:46.085120 140615200499584 voc2012.py:106] Done
# 2021-02-09 15:42:46.891967: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2021-02-09 15:42:46.892064: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# I0209 15:42:49.181178 139673350244224 voc2012.py:92] Class mapping loaded: {'aeroplane': 0, 'bicycle': 1, 'bird': 2, 'boat': 3, 'bottle': 4, 'bus': 5, 'car': 6, 'cat': 7, 'chair': 8, 'cow': 9, 'diningtable': 10, 'dog': 11, 'horse': 12, 'motorbike': 13, 'person': 14, 'pottedplant': 15, 'sheep': 16, 'sofa': 17, 'train': 18, 'tvmonitor': 19}
# I0209 15:42:49.181929 139673350244224 voc2012.py:97] Image list loaded: 3581
# 100% 3581/3581 [00:04<00:00, 845.83it/s]
# I0209 15:42:53.418233 139673350244224 voc2012.py:106] Done

# %%
# !python tools/visualize_dataset.py --dataset ./data/voc_train.tfrecord --classes=./data/voc2012.names
# Out:
# 2021-02-09 15:43:34.672349: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2021-02-09 15:43:34.672405: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# I0209 15:43:36.853887 139864373696384 visualize_dataset.py:22] classes loaded
# 2021-02-09 15:43:36.854503: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-02-09 15:43:36.855489: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-02-09 15:43:36.866739: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2021-02-09 15:43:36.866801: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (89090a21016f): /proc/driver/nvidia/version does not exist
# 2021-02-09 15:43:36.867446: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-02-09 15:43:37.194866: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2021-02-09 15:43:37.195480: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2300000000 Hz
# I0209 15:43:40.120020 139864373696384 visualize_dataset.py:43] labels:
# I0209 15:43:40.120896 139864373696384 visualize_dataset.py:47] 	dog, 1, [0.098      0.45427728 0.576      0.86725664]
# I0209 15:43:40.129452 139864373696384 visualize_dataset.py:52] output saved to: ./output.jpg

# %%
from IPython.display import Image
Image(filename='./output.jpg')

# %%
# !python train.py \
	--dataset ./data/voc_train.tfrecord \
	--val_dataset ./data/voc_val.tfrecord \
	--classes ./data/voc2012.names \
	--num_classes 20 \
	--mode fit --transfer darknet \
	--batch_size 16 \
	--epochs 3 \
	--weights ./checkpoints/yolov3.tf \
	--weights_num_classes 80
# Out:
# 2021-02-09 15:44:39.295531: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2021-02-09 15:44:39.295589: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2021-02-09 15:44:41.581739: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-02-09 15:44:41.582645: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-02-09 15:44:41.606371: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2021-02-09 15:44:41.606445: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (89090a21016f): /proc/driver/nvidia/version does not exist
# 2021-02-09 15:44:41.633471: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-02-09 15:44:50.179587: I tensorflow/core/profiler/lib/profiler_session.cc:136] Profiler session initializing.
# 2021-02-09 15:44:50.179662: I tensorflow/core/profiler/lib/profiler_session.cc:155] Profiler session started.
# 2021-02-09 15:44:50.192545: I tensorflow/core/profiler/lib/profiler_session.cc:172] Profiler session tear down.
# 2021-02-09 15:44:50.417931: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2021-02-09 15:44:50.421755: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2300000000 Hz
# Epoch 1/3
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/util/deprecation.py:605: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# W0209 15:44:53.145914 139882110801792 deprecation.py:537] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/util/deprecation.py:605: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# 2021-02-09 15:45:06.342145: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 354418688 exceeds 10% of free system memory.
# 2021-02-09 15:45:07.354399: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 356124672 exceeds 10% of free system memory.
# 2021-02-09 15:45:07.531630: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 177209344 exceeds 10% of free system memory.
# 2021-02-09 15:45:08.194057: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 177209344 exceeds 10% of free system memory.
# 2021-02-09 15:45:08.776377: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 178917376 exceeds 10% of free system memory.
#       1/Unknown - 46s 46s/step - loss: 9297.8955 - yolo_output_0_loss: 496.0655 - yolo_output_1_loss: 1215.2620 - yolo_output_2_loss: 7575.85252021-02-09 15:45:37.511419: I tensorflow/core/profiler/lib/profiler_session.cc:136] Profiler session initializing.
# 2021-02-09 15:45:37.511483: I tensorflow/core/profiler/lib/profiler_session.cc:155] Profiler session started.
#       2/Unknown - 77s 31s/step - loss: 9925.3208 - yolo_output_0_loss: 663.2161 - yolo_output_1_loss: 1475.9418 - yolo_output_2_loss: 7775.44512021-02-09 15:46:08.669516: I tensorflow/core/profiler/lib/profiler_session.cc:71] Profiler session collecting data.
# 2021-02-09 15:46:08.742183: I tensorflow/core/profiler/lib/profiler_session.cc:172] Profiler session tear down.
# 2021-02-09 15:46:08.831432: I tensorflow/core/profiler/rpc/client/save_profile.cc:137] Creating directory: logs/train/plugins/profile/2021_02_09_15_46_08
# 2021-02-09 15:46:08.881541: I tensorflow/core/profiler/rpc/client/save_profile.cc:143] Dumped gzipped tool data for trace.json.gz to logs/train/plugins/profile/2021_02_09_15_46_08/89090a21016f.trace.json.gz
# 2021-02-09 15:46:08.947069: I tensorflow/core/profiler/rpc/client/save_profile.cc:137] Creating directory: logs/train/plugins/profile/2021_02_09_15_46_08
# 2021-02-09 15:46:08.947349: I tensorflow/core/profiler/rpc/client/save_profile.cc:143] Dumped gzipped tool data for memory_profile.json.gz to logs/train/plugins/profile/2021_02_09_15_46_08/89090a21016f.memory_profile.json.gz
# 2021-02-09 15:46:08.949542: I tensorflow/core/profiler/rpc/client/capture_profile.cc:251] Creating directory: logs/train/plugins/profile/2021_02_09_15_46_08Dumped tool data for xplane.pb to logs/train/plugins/profile/2021_02_09_15_46_08/89090a21016f.xplane.pb
# Dumped tool data for overview_page.pb to logs/train/plugins/profile/2021_02_09_15_46_08/89090a21016f.overview_page.pb
# Dumped tool data for input_pipeline.pb to logs/train/plugins/profile/2021_02_09_15_46_08/89090a21016f.input_pipeline.pb
# Dumped tool data for tensorflow_stats.pb to logs/train/plugins/profile/2021_02_09_15_46_08/89090a21016f.tensorflow_stats.pb
# Dumped tool data for kernel_stats.pb to logs/train/plugins/profile/2021_02_09_15_46_08/89090a21016f.kernel_stats.pb
#
#      19/Unknown - 606s 31s/step - loss: 6864.3402 - yolo_output_0_loss: 547.0500 - yolo_output_1_loss: 1117.8863 - yolo_output_2_loss: 5188.6315
